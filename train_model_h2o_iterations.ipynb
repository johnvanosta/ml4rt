# %%
import pandas as pd
import utm
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import h2o
from h2o.automl import H2OAutoML
from utils.from_latlon import from_latlon
from utils.preprocessing import preprocess
from utils.postprocessing import postprocess_data, location_averaging, calculate_error

seed = 38 # Seed for train/val split

# %%
# Specify data paths
train_data = 'Example_data\Output\Train_test_data\Training_Tag_GPS_locations.xlsx'
test_data = 'Example_data\Output\Train_test_data\Testing_Tag_GPS_locations.xlsx'
radio_tower_xy_path = 'Example_data\Input\Radio_tower_locations\RTEastNorth.xlsx'

# Variable parameters
freq = '3min' # Frequency of data

# Fixed parameters
routine = 'training'
data_type = ['Simulated BTFS', 'BTFS'] # Simulation or Live BTF, or could do both
dimensions = ['xOffset', 'yOffset']
# predictors = ['ant1_mean', 'ant2_mean', 'ant3_mean', 'ant4_mean', 'ant1_count', 'ant2_count', 'ant3_count', 'ant4_count', 'ant1_std', 'ant2_std', 'ant3_std', 'ant4_std', 'mean_std', 'total_count']

# %%
train_data
# Out:
# 'Example_data\\Output\\Train_test_data\\Training_Tag_GPS_locations.xlsx'

# %%
def preprocess_sim_data(sim_data, data_type, freq, tower_locs, routine):
    # Get data
    sim_dat_filt = sim_data[sim_data['Data_type'].isin(data_type)]
    
    sim_dat_filt, predictors = preprocess(sim_dat_filt, freq, routine)
     
    # Calculate easting and northing from lat long
    sim_dat_filt['easting'], sim_dat_filt['northing'], sim_dat_filt['zone_num'], sim_dat_filt['zone_letter'] = from_latlon(sim_dat_filt['POINT_Y'].values, sim_dat_filt['POINT_X'].values)

    # Create a dictionary of the coordinates of the towers
    offset_dict = tower_locs.set_index('TowerID').to_dict()
    point_x = offset_dict['POINT_X']
    point_y = offset_dict['POINT_Y']

    # Standardise the coordinates so that the tower location == 0 on both the x and y axes.
    sim_dat_filt['xOffset'] = sim_dat_filt['easting'] - sim_dat_filt['TowerID'].map(point_x).fillna(0)
    sim_dat_filt['yOffset'] = sim_dat_filt['northing'] - sim_dat_filt['TowerID'].map(point_y).fillna(0)
    
    return sim_dat_filt, predictors

# %%
# Get training data
train_data = pd.read_excel(train_data)
train_data['DateAndTime'] = pd.to_datetime(train_data['DateAndTime'])

# Get testing data
test_data = pd.read_excel(test_data)
test_data['DateAndTime'] = pd.to_datetime(test_data['DateAndTime'])

# Get tower locations
tower_locs = pd.read_excel(radio_tower_xy_path)

# %%
# Preprocess the training and testing data
train_data_preproc, predictors_train = preprocess_sim_data(train_data, data_type, freq, tower_locs, routine)
test_data_preproc, predictors_test = preprocess_sim_data(test_data, data_type, freq, tower_locs, routine)

# Initialise h2o
h2o.init(nthreads = 2)

# For loop to sample training data, train, and test the models and export the result
train_data_length = len(train_data_preproc)
n = 10
run = 1

while n <= 20:
    train_data_preproc_sample = train_data_preproc.sample(n=n, random_state=seed)
    test_data_preproc_n = test_data_preproc.copy()
    results = []

    # Train, save and test the models for each dimension
    for dimension in dimensions:
        # print(f"Training model for {dimension}")
        # Train the model
        variables = predictors_train + [dimension]
        training_input = train_data_preproc_sample[variables]
        train = h2o.H2OFrame(training_input)
        aml = H2OAutoML(max_models=20, seed=seed, stopping_metric='MAE', sort_metric='MAE', max_runtime_secs=3600)
        aml.train(x=predictors_train, y=dimension, training_frame=train)
        print(aml.leaderboard)

        # Save the leader model
        # h2o.save_model(aml.leader, path = f"Example_data\Output\Trained_models\{dimension}", force=True)

        # Make predictions on the test data
        test = h2o.H2OFrame(test_data_preproc_n)
        preds = aml.leader.predict(test)

        # Save predictions to a new column in the test dataframe
        pred_column_name = f"{dimension}_pred"
        test_data_preproc_n[pred_column_name] = preds.as_data_frame()

    # Post process the test predictions to calculate location from the radio tower locations
    test_predictions_tower = postprocess_data(test_data_preproc_n, tower_locs)

    # Location averaging functions
    test_location_estimates = location_averaging(test_predictions_tower)
    test_location_estimates = calculate_error(test_location_estimates)

    # Calculate the mean absolute error of UTM_predictions['distance'] and the standard error
    mean_error = np.mean(test_location_estimates['error_m'])
    std_error = stats.sem(test_location_estimates['error_m'])

    results.append({'r': run, 'n': n, 'mean_error': mean_error, 'std_error': std_error})
    results_df = pd.DataFrame(results)
    results_df.to_csv(f'run_{run}_n{n}_error.csv', index=False)

    print(f'Mean error (+/-SE) = {mean_error} (+/- {std_error})')
    
    n = n+10

# Stop h2o
h2o.cluster().shutdown()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; OpenJDK 64-Bit Server VM Zulu17.36+17-CA (build 17.0.4.1+1-LTS, mixed mode, sharing)
#   Starting server from C:\Users\s5236256\Documents\GitHub\ml4rt\.venv\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\s5236256\AppData\Local\Temp\tmp_xjxbgq3
#   JVM stdout: C:\Users\s5236256\AppData\Local\Temp\tmp_xjxbgq3\h2o_s5236256_started_from_python.out
#   JVM stderr: C:\Users\s5236256\AppData\Local\Temp\tmp_xjxbgq3\h2o_s5236256_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Australia/Brisbane
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.40.0.4
# H2O_cluster_version_age:    2 months and 1 day
# H2O_cluster_name:           H2O_from_python_s5236256_zzkyk4
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.922 Gb
# H2O_cluster_total_cores:    0
# H2O_cluster_allowed_cores:  0
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.11.2 final
# --------------------------  -------------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 21:03:20.380: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_1_20230629_210320  272.651  392.694  154209      nan                    154209
# GBM_grid_1_AutoML_1_20230629_210320_model_4              273.675  394.232  155419      nan                    155419
# StackedEnsemble_AllModels_1_AutoML_1_20230629_210320     274.101  391.946  153622      nan                    153622
# GBM_5_AutoML_1_20230629_210320                           275.995  397.87   158301      nan                    158301
# GBM_grid_1_AutoML_1_20230629_210320_model_5              277.024  394.869  155921      nan                    155921
# GBM_4_AutoML_1_20230629_210320                           279.224  400.478  160383      nan                    160383
# GBM_2_AutoML_1_20230629_210320                           280.077  399.594  159676      nan                    159676
# GBM_3_AutoML_1_20230629_210320                           280.339  401.152  160923      nan                    160923
# GBM_grid_1_AutoML_1_20230629_210320_model_2              280.877  397.105  157693      nan                    157693
# XRT_1_AutoML_1_20230629_210320                           283.481  411.432  169276      nan                    169276
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 21:14:42.888: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_2_20230629_211442  254.133  380.002  144401      nan                    144401
# GBM_5_AutoML_2_20230629_211442                           254.645  380.175  144533      nan                    144533
# StackedEnsemble_AllModels_1_AutoML_2_20230629_211442     255.222  380.199  144551      nan                    144551
# GBM_grid_1_AutoML_2_20230629_211442_model_4              255.705  379.475  144001      nan                    144001
# GBM_2_AutoML_2_20230629_211442                           256.777  384.244  147643      nan                    147643
# GBM_3_AutoML_2_20230629_211442                           258.538  387.837  150417      nan                    150417
# GBM_grid_1_AutoML_2_20230629_211442_model_1              259.366  383.01   146697      nan                    146697
# GBM_4_AutoML_2_20230629_211442                           260.746  389.146  151435      nan                    151435
# GBM_grid_1_AutoML_2_20230629_211442_model_2              261.553  385.605  148691      nan                    148691
# GBM_grid_1_AutoML_2_20230629_211442_model_5              261.707  387.98   150529      nan                    150529
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 288.51141468631016 (+/- 14.912463781618897)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 21:25:51.249: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# GBM_grid_1_AutoML_3_20230629_212551_model_4              273.383  393.921  155173      nan                    155173
# StackedEnsemble_AllModels_1_AutoML_3_20230629_212551     273.736  391.283  153103      nan                    153103
# StackedEnsemble_BestOfFamily_1_AutoML_3_20230629_212551  274.102  391.594  153346      nan                    153346
# GBM_5_AutoML_3_20230629_212551                           275.594  396.608  157298      nan                    157298
# GBM_grid_1_AutoML_3_20230629_212551_model_5              275.65   393.886  155146      nan                    155146
# GBM_2_AutoML_3_20230629_212551                           277.016  396.989  157600      nan                    157600
# GBM_4_AutoML_3_20230629_212551                           278.464  399.226  159382      nan                    159382
# GBM_3_AutoML_3_20230629_212551                           280.694  402.084  161671      nan                    161671
# GBM_grid_1_AutoML_3_20230629_212551_model_2              280.844  397.483  157993      nan                    157993
# XRT_1_AutoML_3_20230629_212551                           282.168  408.639  166986      nan                    166986
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 21:36:54.619: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_4_20230629_213654  253.92   378.831  143513      nan                    143513
# StackedEnsemble_AllModels_1_AutoML_4_20230629_213654     254.257  379.043  143674      nan                    143674
# GBM_grid_1_AutoML_4_20230629_213654_model_4              254.716  378.958  143609      nan                    143609
# GBM_5_AutoML_4_20230629_213654                           255.872  379.759  144217      nan                    144217
# GBM_2_AutoML_4_20230629_213654                           256.715  384.17   147586      nan                    147586
# GBM_3_AutoML_4_20230629_213654                           257.778  386.154  149115      nan                    149115
# GBM_grid_1_AutoML_4_20230629_213654_model_1              258.706  382.501  146307      nan                    146307
# GBM_grid_1_AutoML_4_20230629_213654_model_5              260.672  385.86   148888      nan                    148888
# GBM_4_AutoML_4_20230629_213654                           261.147  389.647  151825      nan                    151825
# GBM_grid_1_AutoML_4_20230629_213654_model_2              261.702  386.571  149437      nan                    149437
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 286.7410817222971 (+/- 15.026396373803202)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 21:48:00.968: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_AllModels_1_AutoML_5_20230629_214800     274.06   391.201  153039      nan                    153039
# StackedEnsemble_BestOfFamily_1_AutoML_5_20230629_214800  274.248  391.165  153010      nan                    153010
# GBM_grid_1_AutoML_5_20230629_214800_model_4              274.39   393.936  155185      nan                    155185
# GBM_grid_1_AutoML_5_20230629_214800_model_5              276.242  392.947  154408      nan                    154408
# GBM_5_AutoML_5_20230629_214800                           276.484  397.339  157878      nan                    157878
# GBM_2_AutoML_5_20230629_214800                           277.054  396.374  157112      nan                    157112
# GBM_3_AutoML_5_20230629_214800                           279.175  399.476  159581      nan                    159581
# GBM_4_AutoML_5_20230629_214800                           279.589  399.702  159762      nan                    159762
# GBM_grid_1_AutoML_5_20230629_214800_model_2              279.653  396.175  156955      nan                    156955
# XRT_1_AutoML_5_20230629_214800                           282.789  410.123  168201      nan                    168201
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 21:59:12.845: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_6_20230629_215912  253.911  377.775  142714      nan                    142714
# StackedEnsemble_AllModels_1_AutoML_6_20230629_215912     253.972  378.123  142977      nan                    142977
# GBM_grid_1_AutoML_6_20230629_215912_model_4              254.561  377.616  142594      nan                    142594
# GBM_5_AutoML_6_20230629_215912                           255.18   380.907  145090      nan                    145090
# GBM_3_AutoML_6_20230629_215912                           257.092  384.13   147556      nan                    147556
# GBM_2_AutoML_6_20230629_215912                           257.522  384.187  147600      nan                    147600
# GBM_grid_1_AutoML_6_20230629_215912_model_1              258.304  381.957  145892      nan                    145892
# GBM_4_AutoML_6_20230629_215912                           260.215  388.589  151001      nan                    151001
# GBM_grid_1_AutoML_6_20230629_215912_model_2              260.961  385.757  148809      nan                    148809
# GBM_grid_1_AutoML_6_20230629_215912_model_5              261.16   386.83   149637      nan                    149637
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 287.4299062225198 (+/- 15.04158162637615)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 22:10:20.786: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_7_20230629_221020  271.873  390.743  152680      nan                    152680
# StackedEnsemble_AllModels_1_AutoML_7_20230629_221020     273.546  390.317  152347      nan                    152347
# GBM_grid_1_AutoML_7_20230629_221020_model_4              273.737  392.795  154288      nan                    154288
# GBM_5_AutoML_7_20230629_221020                           276.121  397.766  158218      nan                    158218
# GBM_grid_1_AutoML_7_20230629_221020_model_5              276.333  393.237  154636      nan                    154636
# GBM_2_AutoML_7_20230629_221020                           278.434  396.795  157447      nan                    157447
# GBM_3_AutoML_7_20230629_221020                           278.937  399.585  159668      nan                    159668
# GBM_4_AutoML_7_20230629_221020                           279.538  400.506  160405      nan                    160405
# GBM_grid_1_AutoML_7_20230629_221020_model_2              279.567  395.674  156558      nan                    156558
# XRT_1_AutoML_7_20230629_221020                           282.269  408.853  167161      nan                    167161
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 22:21:20.737: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_8_20230629_222120  254.559  379.426  143964      nan                    143964
# StackedEnsemble_AllModels_1_AutoML_8_20230629_222120     255.123  379.844  144282      nan                    144282
# GBM_grid_1_AutoML_8_20230629_222120_model_4              255.149  379.271  143847      nan                    143847
# GBM_5_AutoML_8_20230629_222120                           256.987  383.492  147066      nan                    147066
# GBM_3_AutoML_8_20230629_222120                           257.062  384.47   147817      nan                    147817
# GBM_2_AutoML_8_20230629_222120                           258.447  387.248  149961      nan                    149961
# GBM_grid_1_AutoML_8_20230629_222120_model_1              259.092  382.191  146070      nan                    146070
# GBM_grid_1_AutoML_8_20230629_222120_model_5              260.293  386.255  149193      nan                    149193
# GBM_4_AutoML_8_20230629_222120                           260.449  389.293  151549      nan                    151549
# GBM_grid_1_AutoML_8_20230629_222120_model_2              261.481  386.627  149481      nan                    149481
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 286.8001138946683 (+/- 14.875521325620635)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 22:32:31.148: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_9_20230629_223231  273.105  390.293  152329      nan                    152329
# GBM_grid_1_AutoML_9_20230629_223231_model_4              273.315  392.912  154380      nan                    154380
# StackedEnsemble_AllModels_1_AutoML_9_20230629_223231     273.9    390.809  152732      nan                    152732
# GBM_2_AutoML_9_20230629_223231                           276.062  395.841  156690      nan                    156690
# GBM_5_AutoML_9_20230629_223231                           276.579  397.631  158111      nan                    158111
# GBM_grid_1_AutoML_9_20230629_223231_model_5              277.246  394.429  155575      nan                    155575
# GBM_3_AutoML_9_20230629_223231                           278.082  399.228  159383      nan                    159383
# GBM_4_AutoML_9_20230629_223231                           278.393  400.315  160252      nan                    160252
# GBM_grid_1_AutoML_9_20230629_223231_model_2              278.555  395.061  156074      nan                    156074
# XRT_1_AutoML_9_20230629_223231                           279.932  406.124  164937      nan                    164937
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 22:43:22.286: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                      mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_10_20230629_224322  254.038  378.616  143350      nan                    143350
# StackedEnsemble_AllModels_1_AutoML_10_20230629_224322     254.401  378.511  143271      nan                    143271
# GBM_grid_1_AutoML_10_20230629_224322_model_4              254.668  378.752  143453      nan                    143453
# GBM_5_AutoML_10_20230629_224322                           254.955  380.304  144631      nan                    144631
# GBM_2_AutoML_10_20230629_224322                           256.512  384.025  147476      nan                    147476
# GBM_3_AutoML_10_20230629_224322                           256.582  385.378  148516      nan                    148516
# GBM_grid_1_AutoML_10_20230629_224322_model_1              258.088  381.145  145271      nan                    145271
# GBM_4_AutoML_10_20230629_224322                           259.371  387.963  150515      nan                    150515
# GBM_grid_1_AutoML_10_20230629_224322_model_5              259.754  384.281  147672      nan                    147672
# GBM_grid_1_AutoML_10_20230629_224322_model_2              260.749  384.834  148097      nan                    148097
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 288.44393580710926 (+/- 14.892013351327869)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 22:54:48.245: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                      mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_11_20230629_225448  270.878  389.313  151565      nan                    151565
# StackedEnsemble_AllModels_1_AutoML_11_20230629_225448     271.893  388.229  150722      nan                    150722
# GBM_grid_1_AutoML_11_20230629_225448_model_4              273.441  393.721  155016      nan                    155016
# GBM_grid_1_AutoML_11_20230629_225448_model_5              273.591  390.303  152337      nan                    152337
# GBM_5_AutoML_11_20230629_225448                           274.843  395.909  156744      nan                    156744
# XRT_1_AutoML_11_20230629_225448                           275.949  400.652  160522      nan                    160522
# GBM_2_AutoML_11_20230629_225448                           276.936  396.524  157231      nan                    157231
# GBM_4_AutoML_11_20230629_225448                           277.814  398.929  159144      nan                    159144
# GBM_3_AutoML_11_20230629_225448                           278.08   398.832  159067      nan                    159067
# GBM_grid_1_AutoML_11_20230629_225448_model_2              279.348  395.481  156405      nan                    156405
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 23:05:37.971: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                      mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_12_20230629_230537  253.512  377.009  142136      nan                    142136
# GBM_grid_1_AutoML_12_20230629_230537_model_4              253.62   376.616  141839      nan                    141839
# StackedEnsemble_AllModels_1_AutoML_12_20230629_230537     254.051  377.8    142733      nan                    142733
# GBM_5_AutoML_12_20230629_230537                           255.559  380.49   144773      nan                    144773
# GBM_2_AutoML_12_20230629_230537                           256.756  384.213  147619      nan                    147619
# GBM_grid_1_AutoML_12_20230629_230537_model_1              258.018  380.566  144831      nan                    144831
# GBM_3_AutoML_12_20230629_230537                           258.281  385.909  148926      nan                    148926
# GBM_4_AutoML_12_20230629_230537                           258.908  386.837  149643      nan                    149643
# GBM_grid_1_AutoML_12_20230629_230537_model_5              259.618  383.298  146917      nan                    146917
# GBM_grid_1_AutoML_12_20230629_230537_model_2              260.24   384.298  147685      nan                    147685
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 285.75090770482996 (+/- 15.08042570247237)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 23:16:47.413: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                      mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_13_20230629_231647  271.919  391.086  152948      nan                    152948
# GBM_grid_1_AutoML_13_20230629_231647_model_4              273.66   394.493  155625      nan                    155625
# GBM_grid_1_AutoML_13_20230629_231647_model_5              273.897  391.864  153557      nan                    153557
# GBM_5_AutoML_13_20230629_231647                           274.037  395.686  156567      nan                    156567
# StackedEnsemble_AllModels_1_AutoML_13_20230629_231647     274.262  389.621  151804      nan                    151804
# GBM_2_AutoML_13_20230629_231647                           275.239  394.403  155553      nan                    155553
# GBM_3_AutoML_13_20230629_231647                           277.311  397.031  157634      nan                    157634
# GBM_4_AutoML_13_20230629_231647                           278.337  397.881  158309      nan                    158309
# GBM_grid_1_AutoML_13_20230629_231647_model_2              279.015  394.401  155552      nan                    155552
# XRT_1_AutoML_13_20230629_231647                           280.064  405.288  164258      nan                    164258
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 23:27:27.707: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                      mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_14_20230629_232727  252.316  375.881  141287      nan                    141287
# GBM_grid_1_AutoML_14_20230629_232727_model_4              252.788  375.884  141288      nan                    141288
# StackedEnsemble_AllModels_1_AutoML_14_20230629_232727     253.928  377.536  142533      nan                    142533
# GBM_5_AutoML_14_20230629_232727                           254.221  378.456  143229      nan                    143229
# GBM_3_AutoML_14_20230629_232727                           255.902  384.408  147769      nan                    147769
# GBM_2_AutoML_14_20230629_232727                           256.396  383.503  147075      nan                    147075
# GBM_grid_1_AutoML_14_20230629_232727_model_1              256.939  379.429  143967      nan                    143967
# GBM_grid_1_AutoML_14_20230629_232727_model_5              257.899  382.579  146366      nan                    146366
# GBM_4_AutoML_14_20230629_232727                           258.184  386.08   149058      nan                    149058
# GBM_grid_1_AutoML_14_20230629_232727_model_2              259.329  383.609  147156      nan                    147156
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 288.58819198370077 (+/- 14.93383320873603)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 23:38:35.217: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                      mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_15_20230629_233835  270.245  388.438  150884      nan                    150884
# StackedEnsemble_AllModels_1_AutoML_15_20230629_233835     271.568  387.925  150486      nan                    150486
# GBM_grid_1_AutoML_15_20230629_233835_model_4              271.796  390.866  152776      nan                    152776
# GBM_grid_1_AutoML_15_20230629_233835_model_5              273.774  390.115  152190      nan                    152190
# GBM_2_AutoML_15_20230629_233835                           275.729  395.174  156163      nan                    156163
# GBM_5_AutoML_15_20230629_233835                           276.726  396.671  157348      nan                    157348
# GBM_3_AutoML_15_20230629_233835                           276.964  397.778  158228      nan                    158228
# GBM_4_AutoML_15_20230629_233835                           278.028  397.453  157969      nan                    157969
# GBM_grid_1_AutoML_15_20230629_233835_model_2              278.867  394.014  155247      nan                    155247
# XRT_1_AutoML_15_20230629_233835                           279.191  404.751  163824      nan                    163824
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 23:49:27.8: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                      mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_16_20230629_234927  252.861  375.514  141011      nan                    141011
# GBM_grid_1_AutoML_16_20230629_234927_model_4              253.027  375.226  140794      nan                    140794
# StackedEnsemble_AllModels_1_AutoML_16_20230629_234927     253.991  377.192  142274      nan                    142274
# GBM_5_AutoML_16_20230629_234927                           254.175  379.341  143900      nan                    143900
# GBM_2_AutoML_16_20230629_234927                           254.631  381.38   145451      nan                    145451
# GBM_grid_1_AutoML_16_20230629_234927_model_1              256.48   378.809  143496      nan                    143496
# GBM_3_AutoML_16_20230629_234927                           256.789  384.345  147721      nan                    147721
# GBM_grid_1_AutoML_16_20230629_234927_model_5              257.934  383.306  146923      nan                    146923
# GBM_4_AutoML_16_20230629_234927                           258.008  385.693  148759      nan                    148759
# GBM_grid_1_AutoML_16_20230629_234927_model_2              258.734  382.413  146240      nan                    146240
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 285.94234207779556 (+/- 14.957472334595302)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 00:00:32.855: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_17_20230630_00032  268.68   387.689  150303      nan                    150303
# StackedEnsemble_AllModels_1_AutoML_17_20230630_00032     270.322  386.965  149742      nan                    149742
# GBM_grid_1_AutoML_17_20230630_00032_model_4              271.138  390.64   152600      nan                    152600
# GBM_grid_1_AutoML_17_20230630_00032_model_5              272.483  388.829  151188      nan                    151188
# GBM_5_AutoML_17_20230630_00032                           273.147  394.838  155897      nan                    155897
# GBM_2_AutoML_17_20230630_00032                           274.688  394.33   155496      nan                    155496
# GBM_3_AutoML_17_20230630_00032                           275.789  396.645  157327      nan                    157327
# GBM_4_AutoML_17_20230630_00032                           276.741  396.703  157373      nan                    157373
# XRT_1_AutoML_17_20230630_00032                           277.198  402.814  162259      nan                    162259
# GBM_grid_1_AutoML_17_20230630_00032_model_2              278.031  394.025  155256      nan                    155256
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 00:11:24.917: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_18_20230630_01124  252.202  375.478  140984      nan                    140984
# StackedEnsemble_AllModels_1_AutoML_18_20230630_01124     252.569  376.031  141399      nan                    141399
# GBM_grid_1_AutoML_18_20230630_01124_model_4              252.752  375.37   140903      nan                    140903
# GBM_5_AutoML_18_20230630_01124                           254.04   379.026  143661      nan                    143661
# GBM_3_AutoML_18_20230630_01124                           255.044  382.801  146537      nan                    146537
# GBM_grid_1_AutoML_18_20230630_01124_model_1              255.743  378.196  143032      nan                    143032
# GBM_2_AutoML_18_20230630_01124                           256.031  383.571  147127      nan                    147127
# GBM_4_AutoML_18_20230630_01124                           257.251  386.13   149097      nan                    149097
# GBM_grid_1_AutoML_18_20230630_01124_model_5              257.717  381.704  145698      nan                    145698
# GBM_grid_1_AutoML_18_20230630_01124_model_2              259.24   382.522  146323      nan                    146323
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 284.7399097340391 (+/- 14.883034510586029)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 00:22:20.942: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_AllModels_1_AutoML_19_20230630_02220     270.404  386.591  149453      nan                    149453
# StackedEnsemble_BestOfFamily_1_AutoML_19_20230630_02220  270.752  389.224  151496      nan                    151496
# GBM_grid_1_AutoML_19_20230630_02220_model_4              271.617  391.74   153461      nan                    153461
# GBM_grid_1_AutoML_19_20230630_02220_model_5              272.992  389.609  151795      nan                    151795
# GBM_5_AutoML_19_20230630_02220                           274.616  396.03   156839      nan                    156839
# GBM_3_AutoML_19_20230630_02220                           275.625  396.517  157225      nan                    157225
# GBM_2_AutoML_19_20230630_02220                           275.978  395.28   156247      nan                    156247
# GBM_4_AutoML_19_20230630_02220                           276.907  397.586  158074      nan                    158074
# GBM_grid_1_AutoML_19_20230630_02220_model_2              277.047  393.299  154684      nan                    154684
# XRT_1_AutoML_19_20230630_02220                           278.205  403.337  162681      nan                    162681
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 00:33:29.386: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_20_20230630_03329  252.837  377.385  142420      nan                    142420
# GBM_5_AutoML_20_20230630_03329                           253.298  377.571  142560      nan                    142560
# StackedEnsemble_AllModels_1_AutoML_20_20230630_03329     253.457  376.828  141999      nan                    141999
# GBM_grid_1_AutoML_20_20230630_03329_model_4              253.838  375.727  141171      nan                    141171
# GBM_3_AutoML_20_20230630_03329                           255.606  382.027  145944      nan                    145944
# GBM_2_AutoML_20_20230630_03329                           256.452  381.846  145807      nan                    145807
# GBM_grid_1_AutoML_20_20230630_03329_model_1              256.704  378.949  143603      nan                    143603
# GBM_grid_1_AutoML_20_20230630_03329_model_5              257.609  382.059  145969      nan                    145969
# GBM_4_AutoML_20_20230630_03329                           258.514  387.844  150423      nan                    150423
# GBM_grid_1_AutoML_20_20230630_03329_model_2              258.802  382.457  146274      nan                    146274
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 288.3520113062412 (+/- 14.996468840992593)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 00:44:53.779: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_21_20230630_04453  270.506  389.482  151696      nan                    151696
# StackedEnsemble_AllModels_1_AutoML_21_20230630_04453     272.132  388      150544      nan                    150544
# GBM_grid_1_AutoML_21_20230630_04453_model_4              272.454  393.372  154742      nan                    154742
# GBM_grid_1_AutoML_21_20230630_04453_model_5              274.331  390.948  152840      nan                    152840
# GBM_3_AutoML_21_20230630_04453                           275.19   397.593  158080      nan                    158080
# GBM_5_AutoML_21_20230630_04453                           275.754  399.768  159815      nan                    159815
# GBM_2_AutoML_21_20230630_04453                           275.852  395.075  156085      nan                    156085
# GBM_4_AutoML_21_20230630_04453                           277.561  398.973  159179      nan                    159179
# GBM_grid_1_AutoML_21_20230630_04453_model_2              278.507  395.133  156130      nan                    156130
# XRT_1_AutoML_21_20230630_04453                           278.857  404.532  163646      nan                    163646
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 00:55:49.840: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_22_20230630_05549  252.953  375.855  141267      nan                    141267
# GBM_grid_1_AutoML_22_20230630_05549_model_4              253.053  376.167  141502      nan                    141502
# StackedEnsemble_AllModels_1_AutoML_22_20230630_05549     253.878  376.569  141804      nan                    141804
# GBM_5_AutoML_22_20230630_05549                           254.813  378.201  143036      nan                    143036
# GBM_3_AutoML_22_20230630_05549                           255.688  383.377  146978      nan                    146978
# GBM_grid_1_AutoML_22_20230630_05549_model_1              256.255  377.915  142820      nan                    142820
# GBM_2_AutoML_22_20230630_05549                           256.606  383.326  146939      nan                    146939
# GBM_grid_1_AutoML_22_20230630_05549_model_5              256.607  380.923  145102      nan                    145102
# GBM_4_AutoML_22_20230630_05549                           257.493  386.226  149170      nan                    149170
# GBM_grid_1_AutoML_22_20230630_05549_model_2              258.645  381.079  145221      nan                    145221
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 286.75887040935044 (+/- 14.753793767509372)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 01:07:19.759: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_23_20230630_10719  270.779  390.262  152305      nan                    152305
# StackedEnsemble_AllModels_1_AutoML_23_20230630_10719     272.28   387.513  150166      nan                    150166
# GBM_grid_1_AutoML_23_20230630_10719_model_4              272.542  393.007  154454      nan                    154454
# GBM_grid_1_AutoML_23_20230630_10719_model_5              273.368  390.191  152249      nan                    152249
# GBM_2_AutoML_23_20230630_10719                           275.204  395.596  156496      nan                    156496
# GBM_3_AutoML_23_20230630_10719                           275.922  396.442  157166      nan                    157166
# GBM_5_AutoML_23_20230630_10719                           276.318  397.468  157981      nan                    157981
# GBM_grid_1_AutoML_23_20230630_10719_model_2              277.604  395.127  156125      nan                    156125
# GBM_4_AutoML_23_20230630_10719                           279.149  400.292  160234      nan                    160234
# GBM_grid_1_AutoML_23_20230630_10719_model_1              280.801  398.106  158488      nan                    158488
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 01:18:08.91: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_24_20230630_11808  252.056  376.495  141749      nan                    141749
# GBM_grid_1_AutoML_24_20230630_11808_model_4              252.401  376.962  142100      nan                    142100
# StackedEnsemble_AllModels_1_AutoML_24_20230630_11808     253.691  377.178  142263      nan                    142263
# GBM_5_AutoML_24_20230630_11808                           255.099  380.127  144497      nan                    144497
# GBM_3_AutoML_24_20230630_11808                           255.621  383.26   146888      nan                    146888
# GBM_grid_1_AutoML_24_20230630_11808_model_1              256.845  378.484  143250      nan                    143250
# GBM_2_AutoML_24_20230630_11808                           256.863  382.621  146399      nan                    146399
# GBM_grid_1_AutoML_24_20230630_11808_model_5              257.664  380.807  145014      nan                    145014
# GBM_4_AutoML_24_20230630_11808                           258.702  388.241  150731      nan                    150731
# GBM_grid_1_AutoML_24_20230630_11808_model_2              259.236  382.211  146085      nan                    146085
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 285.4775228205076 (+/- 14.722089916144293)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 01:29:14.653: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_25_20230630_12914  269.554  387.686  150301      nan                    150301
# StackedEnsemble_AllModels_1_AutoML_25_20230630_12914     270.496  387.1    149847      nan                    149847
# GBM_grid_1_AutoML_25_20230630_12914_model_5              271.21   388.409  150862      nan                    150862
# GBM_grid_1_AutoML_25_20230630_12914_model_4              272.492  391.505  153276      nan                    153276
# GBM_2_AutoML_25_20230630_12914                           274.232  394.518  155644      nan                    155644
# GBM_5_AutoML_25_20230630_12914                           275.304  397.289  157838      nan                    157838
# GBM_3_AutoML_25_20230630_12914                           276.173  396.393  157127      nan                    157127
# GBM_grid_1_AutoML_25_20230630_12914_model_2              276.784  393.507  154848      nan                    154848
# GBM_4_AutoML_25_20230630_12914                           277.439  398.536  158831      nan                    158831
# GBM_grid_1_AutoML_25_20230630_12914_model_1              279.76   396.761  157419      nan                    157419
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 01:40:10.318: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                     mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_26_20230630_14010  251.248  374.078  139935      nan                    139935
# GBM_grid_1_AutoML_26_20230630_14010_model_4              251.322  374.007  139882      nan                    139882
# StackedEnsemble_AllModels_1_AutoML_26_20230630_14010     252.206  374.053  139916      nan                    139916
# GBM_5_AutoML_26_20230630_14010                           254.065  378.129  142981      nan                    142981
# GBM_3_AutoML_26_20230630_14010                           254.62   382.243  146110      nan                    146110
# GBM_2_AutoML_26_20230630_14010                           255.581  381.286  145379      nan                    145379
# GBM_grid_1_AutoML_26_20230630_14010_model_1              256.102  377.043  142162      nan                    142162
# GBM_grid_1_AutoML_26_20230630_14010_model_5              256.929  380.341  144660      nan                    144660
# GBM_4_AutoML_26_20230630_14010                           257.453  385.949  148957      nan                    148957
# GBM_grid_1_AutoML_26_20230630_14010_model_2              258.262  381.025  145180      nan                    145180
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 286.9308586417698 (+/- 15.119758018318183)
# ...
# StackedEnsemble_BestOfFamily_1_AutoML_108_20230630_172148  249.665  380.841  145040      nan                    145040
# StackedEnsemble_AllModels_1_AutoML_108_20230630_172148     250.673  380.205  144556      nan                    144556
# GBM_grid_1_AutoML_108_20230630_172148_model_4              250.852  382.028  145945      nan                    145945
# GBM_3_AutoML_108_20230630_172148                           251.973  384.327  147707      nan                    147707
# GBM_5_AutoML_108_20230630_172148                           252.95   383.283  146906      nan                    146906
# GBM_grid_1_AutoML_108_20230630_172148_model_5              254.768  384.192  147603      nan                    147603
# GBM_2_AutoML_108_20230630_172148                           255.054  388.145  150656      nan                    150656
# GBM_4_AutoML_108_20230630_172148                           255.638  390.574  152548      nan                    152548
# GBM_grid_1_AutoML_108_20230630_172148_model_2              255.779  384.363  147735      nan                    147735
# GBM_grid_1_AutoML_108_20230630_172148_model_1              256.416  383.769  147279      nan                    147279
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 287.5833181680282 (+/- 14.844019478941592)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 17:34:18.620: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                       mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_109_20230630_173418  272.634  407.634  166165      nan                    166165
# StackedEnsemble_AllModels_1_AutoML_109_20230630_173418     274.368  406.072  164894      nan                    164894
# GBM_grid_1_AutoML_109_20230630_173418_model_4              275.202  410.837  168787      nan                    168787
# GBM_grid_1_AutoML_109_20230630_173418_model_5              276.546  408.709  167043      nan                    167043
# GBM_5_AutoML_109_20230630_173418                           276.621  417.693  174467      nan                    174467
# GBM_2_AutoML_109_20230630_173418                           278.237  414.981  172209      nan                    172209
# GBM_grid_1_AutoML_109_20230630_173418_model_2              279.469  412.806  170409      nan                    170409
# GBM_4_AutoML_109_20230630_173418                           279.674  420.946  177196      nan                    177196
# GBM_3_AutoML_109_20230630_173418                           280.076  419.205  175733      nan                    175733
# XRT_1_AutoML_109_20230630_173418                           280.581  428.206  183360      nan                    183360
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 17:45:32.991: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                       mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_110_20230630_174532  249.37   379.754  144213      nan                    144213
# StackedEnsemble_AllModels_1_AutoML_110_20230630_174532     250.392  380.728  144954      nan                    144954
# GBM_grid_1_AutoML_110_20230630_174532_model_4              250.659  381.347  145425      nan                    145425
# GBM_5_AutoML_110_20230630_174532                           251.905  382.513  146316      nan                    146316
# GBM_3_AutoML_110_20230630_174532                           252.272  385.113  148312      nan                    148312
# GBM_2_AutoML_110_20230630_174532                           253.86   386.223  149168      nan                    149168
# GBM_grid_1_AutoML_110_20230630_174532_model_5              254.723  384.633  147942      nan                    147942
# GBM_grid_1_AutoML_110_20230630_174532_model_2              255.883  385.013  148235      nan                    148235
# GBM_4_AutoML_110_20230630_174532                           255.941  390.656  152612      nan                    152612
# GBM_grid_1_AutoML_110_20230630_174532_model_1              256.49   383.711  147234      nan                    147234
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 286.6022038814557 (+/- 14.772296293337039)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 17:59:13.347: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                       mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_111_20230630_175913  272.014  406.746  165442      nan                    165442
# StackedEnsemble_AllModels_1_AutoML_111_20230630_175913     274.934  407.231  165837      nan                    165837
# GBM_grid_1_AutoML_111_20230630_175913_model_4              275.377  410.784  168743      nan                    168743
# GBM_grid_1_AutoML_111_20230630_175913_model_5              276.742  409.53   167715      nan                    167715
# GBM_5_AutoML_111_20230630_175913                           277.499  417.224  174076      nan                    174076
# GBM_2_AutoML_111_20230630_175913                           278.857  416.787  173711      nan                    173711
# GBM_grid_1_AutoML_111_20230630_175913_model_2              279.04   411.594  169409      nan                    169409
# GBM_3_AutoML_111_20230630_175913                           280.276  420.325  176673      nan                    176673
# GBM_4_AutoML_111_20230630_175913                           280.659  420.333  176680      nan                    176680
# GBM_grid_1_AutoML_111_20230630_175913_model_1              281.424  414.65   171934      nan                    171934
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 18:10:14.476: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                       mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_112_20230630_181014  248.381  379.166  143767      nan                    143767
# StackedEnsemble_AllModels_1_AutoML_112_20230630_181014     249.482  379.957  144368      nan                    144368
# GBM_grid_1_AutoML_112_20230630_181014_model_4              249.737  380.494  144776      nan                    144776
# GBM_3_AutoML_112_20230630_181014                           251.178  384.307  147692      nan                    147692
# GBM_5_AutoML_112_20230630_181014                           251.626  383.303  146921      nan                    146921
# GBM_2_AutoML_112_20230630_181014                           252.949  385.443  148566      nan                    148566
# GBM_grid_1_AutoML_112_20230630_181014_model_5              253.643  383.668  147201      nan                    147201
# GBM_grid_1_AutoML_112_20230630_181014_model_2              254.714  383.655  147191      nan                    147191
# GBM_4_AutoML_112_20230630_181014                           255.02   389.438  151662      nan                    151662
# GBM_grid_1_AutoML_112_20230630_181014_model_1              255.765  382.902  146614      nan                    146614
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 285.2666976061059 (+/- 14.801475155087255)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 18:23:17.319: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                       mae     rmse     mse    rmsle    mean_residual_deviance
# GBM_grid_1_AutoML_113_20230630_182317_model_4              274.28   408.874  167178      nan                    167178
# StackedEnsemble_BestOfFamily_1_AutoML_113_20230630_182317  274.351  406.011  164845      nan                    164845
# StackedEnsemble_AllModels_1_AutoML_113_20230630_182317     274.627  406.513  165253      nan                    165253
# GBM_grid_1_AutoML_113_20230630_182317_model_5              276.766  410.604  168596      nan                    168596
# GBM_5_AutoML_113_20230630_182317                           277.469  416.769  173697      nan                    173697
# GBM_2_AutoML_113_20230630_182317                           277.984  416.052  173100      nan                    173100
# GBM_3_AutoML_113_20230630_182317                           279.404  417.366  174195      nan                    174195
# GBM_grid_1_AutoML_113_20230630_182317_model_2              280.08   412.53   170181      nan                    170181
# GBM_4_AutoML_113_20230630_182317                           280.155  420.493  176814      nan                    176814
# GBM_grid_1_AutoML_113_20230630_182317_model_1              281.402  414.933  172170      nan                    172170
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 18:34:13.530: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                       mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_114_20230630_183413  249.224  379.646  144131      nan                    144131
# StackedEnsemble_AllModels_1_AutoML_114_20230630_183413     250.247  380.335  144655      nan                    144655
# GBM_5_AutoML_114_20230630_183413                           250.548  381.18   145298      nan                    145298
# GBM_grid_1_AutoML_114_20230630_183413_model_4              250.874  381.535  145569      nan                    145569
# GBM_2_AutoML_114_20230630_183413                           252.237  384.196  147606      nan                    147606
# GBM_3_AutoML_114_20230630_183413                           252.68   385.639  148717      nan                    148717
# GBM_grid_1_AutoML_114_20230630_183413_model_5              253.083  381.348  145426      nan                    145426
# GBM_4_AutoML_114_20230630_183413                           254.784  390.434  152439      nan                    152439
# GBM_grid_1_AutoML_114_20230630_183413_model_2              254.829  383.964  147429      nan                    147429
# GBM_grid_1_AutoML_114_20230630_183413_model_1              255.988  382.836  146563      nan                    146563
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Mean error (+/-SE) = 286.75250509843085 (+/- 14.883635877332601)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 18:46:30.251: AutoML: XGBoost is not available; skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# model_id                                                       mae     rmse     mse    rmsle    mean_residual_deviance
# StackedEnsemble_BestOfFamily_1_AutoML_115_20230630_184630  273.037  407.244  165848      nan                    165848
# StackedEnsemble_AllModels_1_AutoML_115_20230630_184630     274.118  406.296  165076      nan                    165076
# GBM_grid_1_AutoML_115_20230630_184630_model_4              274.754  410.282  168331      nan                    168331
# GBM_grid_1_AutoML_115_20230630_184630_model_5              276.776  410.157  168229      nan                    168229
# GBM_2_AutoML_115_20230630_184630                           277.877  415.414  172569      nan                    172569
# GBM_5_AutoML_115_20230630_184630                           278.68   416.818  173738      nan                    173738
# GBM_4_AutoML_115_20230630_184630                           279.41   419.679  176131      nan                    176131
# GBM_3_AutoML_115_20230630_184630                           279.931  419.063  175614      nan                    175614
# GBM_grid_1_AutoML_115_20230630_184630_model_2              280.3    412.555  170201      nan                    170201
# GBM_grid_1_AutoML_115_20230630_184630_model_1              281.52   414.872  172118      nan                    172118
# [22 rows x 6 columns]
#
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 18:57:28.669: AutoML: XGBoost is not available; skipping it.
#
# ██████████████████████████████████████████ (cancelled)
# ---------------------------------------------------------------------------
# H2OJobCancelled                           Traceback (most recent call last)
# Cell In[5], line 26
#      24 train = h2o.H2OFrame(training_input)
#      25 aml = H2OAutoML(max_models=20, seed=seed, stopping_metric='MAE', sort_metric='MAE', max_runtime_secs=3600)
# ---> 26 aml.train(x=predictors_train, y=dimension, training_frame=train)
#      27 print(aml.leaderboard)
#      29 # Save the leader model
#      30 # h2o.save_model(aml.leader, path = f"Example_data\Output\Trained_models\{dimension}", force=True)
#      31
#      32 # Make predictions on the test data
#
# File c:\Users\s5236256\Documents\GitHub\ml4rt\.venv\Lib\site-packages\h2o\automl\_estimator.py:679, in H2OAutoML.train(self, x, y, training_frame, fold_column, weights_column, validation_frame, leaderboard_frame, blending_frame)
#     677 poll_updates = ft.partial(self._poll_training_updates, verbosity=self._verbosity, state={})
#     678 try:
# --> 679     self._job.poll(poll_updates=poll_updates)
#     680 finally:
#     681     poll_updates(self._job, 1)
#
# File c:\Users\s5236256\Documents\GitHub\ml4rt\.venv\Lib\site-packages\h2o\job.py:87, in H2OJob.poll(self, poll_updates)
#      85 # check if failed... and politely print relevant message
#      86 if self.status == "CANCELLED":
# ---> 87     raise H2OJobCancelled("Job<%s> was cancelled by the user." % self.job_key)
#      88 if self.status == "FAILED":
#      89     if (isinstance(self.job, dict)) and ("stacktrace" in list(self.job)):
#
# H2OJobCancelled: Job<$03017f00000132d4ffffffff$_846747eee6047e5da20158c272364257> was cancelled by the user.

# %%
len(train_data_preproc)
# Out:
# 2916

# %%
test_predictions_tower.to_excel("test_tower_predictions.xlsx", index=False)
test_location_estimates.to_excel("UTM_predictions.xlsx", index=False)

# %%
# sorted_df = test_location_estimates.sort_values(by='error_m', ascending=False)
# sorted_df

# %%
train_data_preproc.to_excel("train_data_preproc.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 train_data_preproc.to_excel("train_data_preproc.xlsx", index=False)
#
# NameError: name 'train_data_preproc' is not defined
